# %%
import fglib.financialGraph as fg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Rectangle

# %%
df = pd.read_csv("acc.csv")
df
# Out:
#            date Symbol Series  Prev Close     open     high      low  \
# 0     11-Aug-21    ACC     EQ     2296.95  2297.00  2327.95  2248.55
# 1     10-Aug-21    ACC     EQ     2312.60  2324.00  2330.00  2266.95
# 2     09-Aug-21    ACC     EQ     2341.35  2348.00  2366.55  2304.00
# 3     06-Aug-21    ACC     EQ     2392.20  2382.10  2398.80  2335.40
# 4     05-Aug-21    ACC     EQ     2398.60  2400.05  2413.70  2375.20
# ...         ...    ...    ...         ...      ...      ...      ...
# 4626  07-Jan-03    ACC     EQ      157.05   158.55   158.55   152.35
# 4627  06-Jan-03    ACC     EQ      159.25   160.10   160.25   156.50
# 4628  03-Jan-03    ACC     EQ      164.85   165.60   166.25   158.20
# 4629  02-Jan-03    ACC     EQ      164.35   164.10   166.25   163.05
# 4630  01-Jan-03    ACC     EQ      165.10   166.00   167.00   164.00
#
#       Last Price    close  Average Price   volume      Turnover No. of Trades  \
# ...

# %%
data = fg.Data(df,graphtype="candle")
candle_data = data.send_data()
candle_data
# Out:
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\fglib\financialGraph.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['color'][i] = 'red'
# C:\Users\Divyanshu\Anaconda3\lib\site-packages\fglib\financialGraph.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['color'][i] = 'green'
#            date Symbol Series  Prev Close     open     high      low  \
# 0     11-Aug-21    ACC     EQ     2296.95  2297.00  2327.95  2248.55
# 1     10-Aug-21    ACC     EQ     2312.60  2324.00  2330.00  2266.95
# 2     09-Aug-21    ACC     EQ     2341.35  2348.00  2366.55  2304.00
# ...

# %%
candle_data = candle_data.head(100)

# %%
fig, ax = plt.subplots(1, figsize=(18,8))
lines = []
patches = []
for i in candle_data.index:
    if candle_data['close'][i] >=candle_data['open'][i]:
        lower = candle_data['open'][i]
        height = candle_data['close'][i] - candle_data['open'][i]
    else:
        lower = candle_data['close'][i]
        height = candle_data['open'][i] - candle_data['close'][i]

    vline = Line2D(xdata=(i, i), ydata=(candle_data['low'][i],candle_data['high'][i]),color=candle_data['color'][i])

    rect = Rectangle(xy=(i-0.3,lower),width=0.6,height=height,facecolor=candle_data['color'][i],edgecolor='k')
    rect.set_alpha(alpha=1.0)

    lines.append(vline)
    patches.append(rect)
    ax.add_line(vline)
    ax.add_patch(rect)
ax.autoscale_view()
ax.set_ylabel('price')
ax.set_title('ACC')
ax.set_xticks(candle_data.index[::10])
ax.set_xticklabels(candle_data["date"][::10])
plt.show()
