# %%
import fglib
import pandas as pd

# %%
df = pd.read_csv("acc.csv")
df
# Out:
#            date Symbol Series  Prev Close     open     high      low  \
# 0     11-Aug-21    ACC     EQ     2296.95  2297.00  2327.95  2248.55
# 1     10-Aug-21    ACC     EQ     2312.60  2324.00  2330.00  2266.95
# 2     09-Aug-21    ACC     EQ     2341.35  2348.00  2366.55  2304.00
# 3     06-Aug-21    ACC     EQ     2392.20  2382.10  2398.80  2335.40
# 4     05-Aug-21    ACC     EQ     2398.60  2400.05  2413.70  2375.20
# ...         ...    ...    ...         ...      ...      ...      ...
# 4626  07-Jan-03    ACC     EQ      157.05   158.55   158.55   152.35
# 4627  06-Jan-03    ACC     EQ      159.25   160.10   160.25   156.50
# 4628  03-Jan-03    ACC     EQ      164.85   165.60   166.25   158.20
# 4629  02-Jan-03    ACC     EQ      164.35   164.10   166.25   163.05
# 4630  01-Jan-03    ACC     EQ      165.10   166.00   167.00   164.00
#
#       Last Price    close  Average Price   volume      Turnover No. of Trades  \
# ...

# %%
data = fglib.financialGraph.Data(df,graphtype="candle")
print(data.renko())
# Out:
# None
