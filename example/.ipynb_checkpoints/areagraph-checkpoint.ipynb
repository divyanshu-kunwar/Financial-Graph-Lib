# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("ACC.csv")
df.head(10)
# Out:
#         date Symbol Series  Prev Close     open     high      low  Last Price  \
# 0  11-Aug-21    ACC     EQ     2296.95  2297.00  2327.95  2248.55     2276.90
# 1  10-Aug-21    ACC     EQ     2312.60  2324.00  2330.00  2266.95     2296.00
# 2  09-Aug-21    ACC     EQ     2341.35  2348.00  2366.55  2304.00     2322.30
# 3  06-Aug-21    ACC     EQ     2392.20  2382.10  2398.80  2335.40     2344.00
# 4  05-Aug-21    ACC     EQ     2398.60  2400.05  2413.70  2375.20     2390.00
# 5  04-Aug-21    ACC     EQ     2433.10  2433.00  2454.95  2393.00     2398.00
# 6  03-Aug-21    ACC     EQ     2424.00  2420.00  2440.80  2392.00     2429.55
# 7  02-Aug-21    ACC     EQ     2394.10  2395.00  2434.40  2381.20     2424.00
# 8  30-Jul-21    ACC     EQ     2364.00  2365.00  2415.00  2360.00     2395.50
# 9  29-Jul-21    ACC     EQ     2393.90  2400.00  2413.00  2349.80     2374.00
#
#      close  Average Price  volume      Turnover No. of Trades Deliverable Qty  \
# ...

# %% [markdown]
# # Plotting Graph
# we have successfully fetch the data with 15 columns . Let's plot a area graph where date is plotted on x-axis while close price is plotted on y-axis.

# %% [markdown]
# First let's remove date as the default index and change the format of date to date-month-year to do so you need to use pd.to_datetime() function and then format the string.

# %%
df = df.reset_index()
df['date'] = pd.to_datetime(df['date']).dt.strftime('%d-%b-%y')

# %% [markdown]
# #### create a subplot with variable name fig and it's axes as ax .
# Plot index vs close price and then make the graph looks beautiful by adding labels and titles. To prevent messing up text on x-axis. you can use [::150] to select every 150th index from the list.

# %%
fig, ax = plt.subplots(1, figsize=(18,8))
plt.plot(df.index,df['close'])
plt.fill_between(df.index,df['close'], color='green',alpha =0.2)
ax.set_ylabel('Closing Price')
ax.set_title('ACC')
ax.set_xticks(df.index[::300])
ax.set_xticklabels(df["date"][::300])
"graph plotted"
# Out:
# 'graph plotted'
